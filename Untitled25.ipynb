# %% [markdown]
# <a href="https://colab.research.google.com/github/ALDO12062004/EDP2/blob/main/Untitled25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Caminata aleatoria 1D

# %% [markdown]
# # Definición del problema

# %% [markdown]
# Implementar una caminata aleatoria 1D, con probabilidad p de moverse a la derecha y probabilidad q de moverse a la izquierda, tal que $$p + q = 1.$$

# %% [markdown]
# Definimos las librerias

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Definimos una secuencia de variables aleatorias $X_1, X_2, \dots, X_n$ donde cada $X_i$ representa un paso.
#
# Definimos la función para la pisición final
# $$ x_i = +1 \hspace{0.2cm}{\text{con probabilidad p a la derecha}}  $$
# $$ x_i = -1 \hspace{0.2cm}{\text{con probabilidad q a la izquierda}}  $$

# %%
def caminata_aleatoria_1d(n_pasos, p):
    """
    Simula una caminata aleatoria en 1D.
    n_pasos: Número total de pasos.
    p: Probabilidad de moverse a la derecha (+1).
    """
    q = 1 - p
    # Generamos los pasos: +1 o -1 basados en la probabilidad p
    pasos = np.random.choice([1, -1], size=n_pasos, p=[p, q])

    # La trayectoria es la suma acumulada de los pasos
    trayectoria = np.cumsum(pasos)
    # Insertamos el origen (0) al inicio
    trayectoria = np.insert(trayectoria, 0, 0)

    return trayectoria

# %% [markdown]
# La posición final $S_n$ tras $n$ pasos se define como
#
# $$ S_n = \sum_{i=1}^n X_i $$

# %% [markdown]
# Definimos los parámetros

# %%
# Parámetros de la simulación
N = 100    # Número de pasos
P_DERECHA = 0.5  # Ligeramente sesgado a la derecha

# %% [markdown]
# Ejeciutamos la función

# %%
# Ejecución
recorrido = caminata_aleatoria_1d(N, P_DERECHA)

# %% [markdown]
# Implementación gráfica

# %%
# Visualización
plt.figure(figsize=(10, 5))
plt.plot(recorrido, color='#2c3e50', linewidth=1)
plt.axhline(0, color='blue', linestyle='--', alpha=0.5)
plt.title(f"Caminata Aleatoria 1D (p={P_DERECHA}, q={1-P_DERECHA:.2f})")
plt.xlabel("Número de Pasos")
plt.ylabel("Posición")
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# # Conclusiones

# %% [markdown]
# # ***1. ¿Cuál es la probabilidad de que la partícula regrese al origen?***
# Respuesta: En una caminata aleatoria 1D simétrica ($p = 0.5$), la probabilidad de regresar al origen es 1 (100%). Si le das tiempo infinito a la partícula, eventualmente tocará el punto de partida. Sin embargo, si la caminata tiene un sesgo ($p \neq q$), existe una probabilidad distinta de cero de que la partícula se aleje para siempre y nunca regrese.

# %%
s1 = caminata_aleatoria_1d (100, 0.5)
for i in (1+len(s1)):
    if s1[i] == 0:
      k = k+1
      print(k)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1959411613.py in <cell line: 0>()
#       1 s1 = caminata_aleatoria_1d (100, 0.5)
# ----> 2 for i in (1+len(s1)):
#       3     if s1[i] == 0:
#       4       k = k+1
#       5       print(k)
#
# TypeError: 'int' object is not iterable
